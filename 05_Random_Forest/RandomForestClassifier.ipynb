# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)

# %%
rf.score(X_test, y_test)

# %%
y_predict_rf = rf.predict(X_test)
print(y_predict_rf)

# %%
rf.estimators_ # give all the decsion tree

# %%
plt.figure(figsize= (20,20))
tree.plot_tree(rf.estimators_[0], filled=True)

# %% [markdown]
# Hyperparameter Tunning: GridSearchCV and  RandomSearchCV

# %%
grid_param = {
    "n_estimators" : [5, 10, 50, 100, 120, 150],
    "criterion" : ['gini', 'entropy'],
    "max_depth" : range(10),
    "min_sample_leaf" : range(10)

}
# in "n_estimators" whatever number has given, that number of time of DT will try to make

# %%
from sklearn.model_selection import GridSearchCV
grid_search_rf =GridSearchCV(param_grid = grid_param, cv = 10, n_job = 6, verbose = 1, estimator = rf)
grid_search_rf.fit(X_train, y_train)

# %%
grid_search_rf.best+params_

# %%
rf_new = RandomForestClassifier(n_estimators =120, criterion = "entropy", max_depth = 4 )
rf_new.fit(X_train, y_train)

# %%
rf_new.score(X_test, y_test)
